# %%
from tf_unet import unet
from scipy.misc import imread
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

tf.reset_default_graph()

# %%
net = unet.Unet(layers=3, features_root=16)
x_test = np.array([imread('parcels/00999.png')[:, :, :3]])
prediction = net.predict("./unet_trained/model.ckpt", x_test)

fig, ax = plt.subplots(1, 2, sharex=True, sharey=True, figsize=(12,5))
ax[0].imshow(x_test[0,...,0], aspect="auto")
# ax[1].imshow(y_test[0,...,1], aspect="auto")
mask = prediction[0,...,1] > 0.9
ax[1].imshow(mask, aspect="auto")
# Out:
# 2018-06-10 10:07:06,741 Layers 3, features 16, filter size 3x3, pool size: 2x2
# INFO:tensorflow:Restoring parameters from ./unet_trained/model.ckpt
# /Users/james/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#
# 2018-06-10 10:07:08,120 Restoring parameters from ./unet_trained/model.ckpt
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# ~/miniconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1321     try:
# -> 1322       return fn(*args)
#    1323     except errors.OpError as e:
#
# ~/miniconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
# ...

# %%
# %matplotlib inline 
# %config InlineBackend.figure_format = 'retina'

import json
import numpy as np

import matplotlib.pyplot as plt
import numpy as np

with open('votes.json', 'r') as f:
    votes = json.load(f)
total_good = 0
total_okay = 0
total_bad = 0
vote_counts = []
pdenom, tdenom, qdenom = 0, 0, 0
pnumer, tnumer, qnumer = 0.0, 0.0, 0.0
pcount, tcount, qcount = 0, 0, 0
for key, vote in votes.items():
    good = vote.get('good', 0)
    okay = vote.get('okay', 0)
    bad = vote.get('bad', 0)
    total_good += good
    total_okay += okay
    total_bad += bad
    if key.startswith('q'):
        qcount += 1
        qdenom += good + okay + bad
        qnumer += good + 0.5 * okay
        print(key, vote)
    if key.startswith('t'):
        tcount += 1
        tdenom += good + okay + bad
        tnumer += good + 0.5 * okay
    if key.startswith('p'):
        pcount += 1
        pdenom += good + okay + bad
        pnumer += good + 0.5 * okay
    vote_counts.append(good + okay + bad)

print('\n'
      'Training: {} ± {}% ({} votes for {} images)\n'
      'UNet: {} ± {}% ({} votes for {} images)\n'
      'Queries: {} ± {}% ({} votes for {} images)'.format(
    np.round(100.0 * tnumer / tdenom, 1), np.round(100.0 * np.sqrt(1.0 / tdenom), 1), tdenom, tcount,
    np.round(100.0 * pnumer / pdenom, 1), np.round(100.0 * np.sqrt(1.0 / pdenom), 1), pdenom, pcount,
    np.round(100.0 * qnumer / qdenom, 1), np.round(100.0 * np.sqrt(1.0 / qdenom), 1), qdenom, qcount))
 
objects = ('Training', 'UNet', 'Queries')
y_pos = np.arange(len(objects))
performance = [tnumer / tdenom, pnumer / pdenom, qnumer / qdenom]
errors = [np.sqrt(1.0 / tdenom), np.sqrt(1.0 / pdenom), np.sqrt(1.0 / qdenom)]
colors = ['red', 'green', 'orange']

plt.rcParams.update({'font.size': 22})
fig = plt.figure(figsize=(10, 6))
plt.ylim(0, 1)
container = plt.bar(y_pos[:2], performance[:2], yerr=errors[:2], align='center', alpha=0.5,
                    color=colors[:2], ecolor='gray', capsize=10, error_kw={'elinewidth':3, 'markeredgewidth':3})
plt.xticks(y_pos[:2], objects[:2])
plt.yticks((0, 0.5, 1), ('Bad', 'Okay', 'Good'))
plt.ylabel('User Rating')
plt.title('Quality of tree masks')
 
plt.show()
# Out:
# qb642c168-6027-7caa-06d1-cf52c6401187 {'good': 16, 'okay': 0, 'bad': 0}
# q5da459d4-89e7-6bde-a603-565ba6346ca5 {'good': 0, 'okay': 0, 'bad': 9}
# qbd0a9836-52f4-a9b3-6951-1032911fc7f0 {'good': 11, 'okay': 1, 'bad': 0}
# qe0cbdb22-073d-3a68-1dd1-73980fe44bb7 {'good': 0, 'okay': 3, 'bad': 6}
# q6cb9c73b-b916-b527-98a8-09ca2ad3fd67 {'good': 2, 'okay': 7, 'bad': 0}
# q735f1405-d114-6e73-4134-0c59b433de58 {'good': 3, 'okay': 4, 'bad': 1}
# qf4a16ad4-b150-6496-41ba-dad011559b9b {'good': 3, 'okay': 2, 'bad': 1}
# q84169ecc-91ad-6039-b13b-7a4e8a3df969 {'good': 0, 'okay': 2, 'bad': 0}
# q32b2ea9f-7346-3408-8b5f-81dda062ca64 {'good': 1, 'okay': 0, 'bad': 1}
# q05484a4b-a047-8330-2ca0-9d8554c29549 {'good': 0, 'okay': 0, 'bad': 1}
# q5c1a284d-8cad-14c8-36ce-49b796055d54 {'good': 1, 'okay': 0, 'bad': 0}
# q17fb637c-5f94-49ea-5ffc-fa2836fb5ec7 {'good': 0, 'okay': 0, 'bad': 1}
# q6465bc87-c28e-89d3-ae75-7042c632ecf9 {'good': 1, 'okay': 0, 'bad': 0}
#
# ...

# %%
import pandas as pd

svs = pd.read_csv('humantree/text/shade-values.csv', names=['id', 'fraction', 'value', 'sqft'])

svs = svs.mask(svs['sqft'] > 1000000.0).dropna()
svs = svs.mask(svs['value'] > 2000000.0).dropna()

print(max(svs['sqft']))

# x = svs['sqft'].tolist()
x = svs['fraction']
y = svs['value']/svs['sqft']
# y = svs['value']
y = svs['sqft']

plt.scatter(x, y)

m, b = np.polyfit(x, y, 1)

print(m, b)

plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1))(np.unique(x)))
# Out:
# 17000.0
# 1930.9441865458996 3207.5995681680793
